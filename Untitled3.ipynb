# %% [markdown]
# <a href="https://colab.research.google.com/github/Lui7Script/Anima-o-com-L-pis/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from urllib.request import Request, urlopen
from bs4 import BeautifulSoup as soup
url = 'https://publicacoes.estadao.com.br/guia-da-faculdade/?post_type=faculdades_2021&ano=2021&s=+++&tipo=&modalidade=&estado=&cidade=&classificacao='
req = Request(url , headers={'User-Agent': 'Mozilla/5.0'})

webpage = urlopen(req).read()
page_soup = soup(webpage, "html.parser")
print(page_soup.text)
# Out:
# Você pesquisou por - Guia da Faculdade
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# {"@context":"https://schema.org","@graph":[{"@type":"WebSite","@id":"https://publicacoes.estadao.com.br/guia-da-faculdade/#website","url":"https://publicacoes.estadao.com.br/guia-da-faculdade/","name":"Guia da Faculdade","potentialAction":{"@type":"SearchAction","target":"https://publicacoes.estadao.com.br/guia-da-faculdade/?s={search_term_string}","query-input":"required name=search_term_string"}},{"@type":"SearchResultsPage","@id":"https://publicacoes.estadao.com.br/guia-da-faculdade/search/+++/#webpage","url":"https://publicacoes.estadao.com.br/guia-da-faculdade/search/+++/","inLanguage":"pt-BR","name":"Voc\u00ea pesquisou por - Guia da Faculdade","isPartOf":{"@id":"https://publicacoes.estadao.com.br/guia-da-faculdade/#website"}}]}
#
#
#
#
# ...
